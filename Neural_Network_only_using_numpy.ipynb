# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

data = pd.read_csv('./train.csv')
data = np.array(data)
m, n = data.shape
np.random.shuffle(data) # shuffle before splitting into dev and training sets

data_dev = data[0:1000].T
Y_dev = data_dev[0]
X_dev = data_dev[1:n]
X_dev = X_dev / 255.

data_train = data[1000:m].T
Y_train = data_train[0]
X_train = data_train[1:n]
X_train = X_train / 255.
_,m_train = X_train.shape

# %%
def init_params():
    W1 = np.random.rand(64, 784) - 0.5  # First hidden layer with 64 neurons
    b1 = np.random.rand(64, 1) - 0.5
    
    W2 = np.random.rand(32, 64) - 0.5   # Second hidden layer with 32 neurons
    b2 = np.random.rand(32, 1) - 0.5

    W3 = np.random.rand(16, 32) - 0.5   # Third hidden layer with 16 neurons
    b3 = np.random.rand(16, 1) - 0.5
    
    W4 = np.random.rand(10, 16) - 0.5    # Output layer with 10 neurons
    b4 = np.random.rand(10, 1) - 0.5
    return W1, b1, W2, b2, W3, b3, W4, b4

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
def ReLU(Z):
    return np.maximum(Z, 0)

# %%
def softmax(Z):
    A = np.exp(Z) / np.sum(np.exp(Z), axis=0)
    return A

# %%
# Forward propagation
def forward_prop(W1, b1, W2, b2,W3,b3,W4,b4, X):
    Z1 = W1.dot(X) + b1
    A1 = ReLU(Z1)
    Z2 = W2.dot(A1) + b2
    A2 = sigmoid(Z2)
    Z3 = W3.dot(A2) + b3
    A3 = ReLU(Z3)
    Z4 = W4.dot(A3) + b4
    A4 = softmax(Z4)
    return Z1, A1, Z2, A2,Z3,A3,Z4,A4

# %%
# Backward propagation
def ReLU_deriv(Z):
    return Z > 0

# %%
def sigmoid_deriv(z):
    sig = sigmoid(z)
    return sig * (1 - sig)

# %%
def one_hot(Y):
    one_hot_Y = np.zeros((Y.size, Y.max() + 1))
    one_hot_Y[np.arange(Y.size), Y] = 1
    return one_hot_Y.T

# %%
def backward_prop(Z1, A1, Z2, A2, Z3, A3, Z4, A4, W1, W2, W3, W4, X, Y):
    one_hot_Y = one_hot(Y)
    m = X.shape[1]
    
    # Layer 4 (Output)
    dZ4 = A4 - one_hot_Y
    dW4 = 1 / m * dZ4.dot(A3.T)
    db4 = 1 / m * np.sum(dZ4, axis=1, keepdims=True)

    # Layer 3
    dZ3 = W4.T.dot(dZ4) * ReLU_deriv(Z3)
    dW3 = 1 / m * dZ3.dot(A2.T)
    db3 = 1 / m * np.sum(dZ3, axis=1, keepdims=True)

    # Layer 2
    dZ2 = W3.T.dot(dZ3) * sigmoid_deriv(Z2)
    dW2 = 1 / m * dZ2.dot(A1.T)
    db2 = 1 / m * np.sum(dZ2, axis=1, keepdims=True)

    # Layer 1
    dZ1 = W2.T.dot(dZ2) * ReLU_deriv(Z1)
    dW1 = 1 / m * dZ1.dot(X.T)
    db1 = 1 / m * np.sum(dZ1, axis=1, keepdims=True)

    return dW1, db1, dW2, db2, dW3, db3, dW4, db4

# %%
# Parameter updates
def update_params(W1, b1, W2, b2, W3, b3, W4, b4, 
                  dW1, db1, dW2, db2, dW3, db3, dW4, db4, 
                  alpha):
    W1 -= alpha * dW1
    b1 -= alpha * db1
    W2 -= alpha * dW2
    b2 -= alpha * db2
    W3 -= alpha * dW3
    b3 -= alpha * db3
    W4 -= alpha * dW4
    b4 -= alpha * db4
    return W1, b1, W2, b2, W3, b3, W4, b4

# %%
# Prediction and accuracy
def get_predictions(A4):
    return np.argmax(A4, axis=0)

# %%
def get_accuracy(predictions, Y):
    return np.sum(predictions == Y) / Y.size

# %%
# Training the model
def gradient_descent(X, Y, alpha, iterations):
    W1, b1, W2, b2,W3,b3,W4,b4 = init_params()
    for i in range(iterations):
        Z1, A1, Z2, A2,Z3,A3,Z4,A4 = forward_prop(W1, b1, W2, b2,W3,b3,W4,b4, X)
        dW1, db1, dW2, db2,dW3,db3,dW4,db4 = backward_prop(Z1, A1, Z2, A2,Z3,A3,Z4,A4, W1, W2,W3,W4,X, Y)
        W1, b1, W2, b2,W3,b3,W4,b4 = update_params(W1, b1, W2, b2,W3,b3,W4,b4,dW1, db1, dW2, db2,dW3,db3,dW4,db4,alpha)
# Iteration 1440, Accuracy: 95.23%
# Iteration 1450, Accuracy: 95.25%
# Iteration 1460, Accuracy: 95.28%
# Iteration 1470, Accuracy: 95.30%
# Iteration 1480, Accuracy: 95.32%
# Iteration 1490, Accuracy: 95.33%
# Iteration 1500, Accuracy: 95.34%
# Iteration 1510, Accuracy: 95.37%
# Iteration 1520, Accuracy: 95.39%
# Iteration 1530, Accuracy: 95.41%
# Iteration 1540, Accuracy: 95.44%
# Iteration 1550, Accuracy: 95.47%
# Iteration 1560, Accuracy: 95.49%
# Iteration 1570, Accuracy: 95.51%
# Iteration 1580, Accuracy: 95.52%
# Iteration 1590, Accuracy: 95.55%
# Iteration 1600, Accuracy: 95.57%
# Iteration 1610, Accuracy: 95.59%
# Iteration 1620, Accuracy: 95.60%
# Iteration 1630, Accuracy: 95.62%
# Iteration 1640, Accuracy: 95.62%
# Iteration 1650, Accuracy: 95.64%
# Iteration 1660, Accuracy: 95.65%
# Iteration 1670, Accuracy: 95.66%
# Iteration 1680, Accuracy: 95.69%
# Iteration 1690, Accuracy: 95.72%
# Iteration 1700, Accuracy: 95.74%
# Iteration 1710, Accuracy: 95.77%
# Iteration 1720, Accuracy: 95.79%
# Iteration 1730, Accuracy: 95.80%
# Iteration 1740, Accuracy: 95.82%
# Iteration 1750, Accuracy: 95.85%
# Iteration 1760, Accuracy: 95.87%
# Iteration 1770, Accuracy: 95.90%
# Iteration 1780, Accuracy: 95.92%
# Iteration 1790, Accuracy: 95.94%
# Iteration 1800, Accuracy: 95.95%
# Iteration 1810, Accuracy: 95.97%
# Iteration 1820, Accuracy: 95.99%
# Iteration 1830, Accuracy: 96.01%
# Iteration 1840, Accuracy: 96.02%
# Iteration 1850, Accuracy: 96.05%
# Iteration 1860, Accuracy: 96.06%
# Iteration 1870, Accuracy: 96.10%
# Iteration 1880, Accuracy: 96.12%
# Iteration 1890, Accuracy: 96.15%
# Iteration 1900, Accuracy: 96.16%
# Iteration 1910, Accuracy: 96.18%
# Iteration 1920, Accuracy: 96.19%
# Iteration 1930, Accuracy: 96.21%
# Iteration 1940, Accuracy: 96.23%
# Iteration 1950, Accuracy: 96.23%
# Iteration 1960, Accuracy: 96.26%
# Iteration 1970, Accuracy: 96.27%
# Iteration 1980, Accuracy: 96.30%
# Iteration 1990, Accuracy: 96.32%

# %%
def make_predictions(X, W1, b1, W2, b2, W3, b3, W4, b4):
    # Perform forward propagation
    _, _, _, _, _, _, _, A4 = forward_prop(W1, b1, W2, b2, W3, b3, W4, b4, X)
    predictions = get_predictions(A4)  # Get predicted class labels
    return predictions

# %%
def get_dev_accuracy(X_dev, Y_dev, W1, b1, W2, b2, W3, b3, W4, b4):
    dev_predictions = make_predictions(X_dev, W1, b1, W2, b2, W3, b3, W4, b4)
    accuracy = get_accuracy(dev_predictions, Y_dev)
    print(f"Dev set accuracy: {accuracy * 100:.2f}%")  # Display accuracy in percentage

# %%
# Get accuracy on the dev set
get_dev_accuracy(X_dev, Y_dev, W1, b1, W2, b2, W3, b3, W4, b4)
# Out:
# Dev set accuracy: 94.40%
